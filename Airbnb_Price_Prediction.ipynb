# %% [markdown]
# # Importing Libraries

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.10-cp313-cp313-win_amd64.whl.metadata (1.5 kB)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from catboost) (3.10.3)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from catboost) (2.2.6)
# Requirement already satisfied: pandas<4.0,>=0.24 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from catboost) (2.2.3)
# Requirement already satisfied: scipy in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in c:\Users\DELL\anaconda3\Lib\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from matplotlib->catboost) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from plotly->catboost) (9.1.2)
# Downloading catboost-1.2.10-cp313-cp313-win_amd64.whl (100.2 MB)
#    ---------------------------------------- 0.0/100.2 MB ? eta -:--:--
#    ---------------------------------------- 0.5/100.2 MB 9.5 MB/s eta 0:00:11
#    - -------------------------------------- 3.7/100.2 MB 14.5 MB/s eta 0:00:07
#    --- ------------------------------------ 7.6/100.2 MB 16.4 MB/s eta 0:00:06
#    ---- ----------------------------------- 11.8/100.2 MB 17.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 14.9/100.2 MB 16.9 MB/s eta 0:00:06
#    ------- -------------------------------- 18.1/100.2 MB 16.3 MB/s eta 0:00:06
#    -------- ------------------------------- 21.2/100.2 MB 15.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 25.7/100.2 MB 16.6 MB/s eta 0:00:05
#    ------------ --------------------------- 30.7/100.2 MB 17.3 MB/s eta 0:00:05
#    -------------- ------------------------- 35.7/100.2 MB 17.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 40.4/100.2 MB 18.4 MB/s eta 0:00:04
#    ----------------- ---------------------- 44.8/100.2 MB 18.7 MB/s eta 0:00:03
#    ------------------- -------------------- 49.8/100.2 MB 19.1 MB/s eta 0:00:03
#    --------------------- ------------------ 54.5/100.2 MB 19.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 59.2/100.2 MB 19.6 MB/s eta 0:00:03
#    ------------------------- -------------- 64.2/100.2 MB 19.8 MB/s eta 0:00:02
#    --------------------------- ------------ 69.2/100.2 MB 20.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 73.9/100.2 MB 20.2 MB/s eta 0:00:02
#    ------------------------------- -------- 78.6/100.2 MB 20.3 MB/s eta 0:00:02
#    --------------------------------- ------ 83.4/100.2 MB 20.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 88.1/100.2 MB 20.5 MB/s eta 0:00:01
#    ------------------------------------- -- 92.8/100.2 MB 20.6 MB/s eta 0:00:01
#    ---------------------------------------  97.8/100.2 MB 20.8 MB/s eta 0:00:01
#    --------------------------------------  100.1/100.2 MB 20.8 MB/s eta 0:00:01
#    --------------------------------------  100.1/100.2 MB 20.8 MB/s eta 0:00:01
#    --------------------------------------  100.1/100.2 MB 20.8 MB/s eta 0:00:01
#    ---------------------------------------- 100.2/100.2 MB 18.4 MB/s  0:00:05
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Installing collected packages: graphviz, catboost
#
#    ---------------------------------------- 0/2 [graphviz]
#    ---------------------------------------- 0/2 [graphviz]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    -------------------- ------------------- 1/2 [catboost]
#    ---------------------------------------- 2/2 [catboost]
#
# Successfully installed catboost-1.2.10 graphviz-0.21
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import  LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
#from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Importing Data

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\Airbnb Data\Airbnb_Data.csv")

# %% [markdown]
# # Data Exploration

# %%
df
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# 2      {TV,"Cable TV","Wireless Internet","Air condit...             5
# 3      {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4
# 4      {TV,Internet,"Wireless Internet","Air conditio...             2
# ...                                                  ...           ...
# 74106                                                 {}             1
# 74107  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4
# 74108  {TV,Internet,"Wireless Internet","Air conditio...             5
# 74109  {TV,"Wireless Internet","Air conditioning",Kit...             2
# 74110  {TV,Internet,"Wireless Internet",Kitchen,"Free...             4
#
#        bathrooms  bed_type cancellation_policy  cleaning_fee  ...   latitude  \
# 0            1.0  Real Bed              strict          True  ...  40.696524
# 1            1.0  Real Bed              strict          True  ...  40.766115
# 2            1.0  Real Bed            moderate          True  ...  40.808110
# 3            1.0  Real Bed            flexible          True  ...  37.772004
# 4            1.0  Real Bed            moderate          True  ...  38.925627
# ...          ...       ...                 ...           ...  ...        ...
# 74106        1.0  Real Bed            flexible         False  ...  40.709025
# 74107        2.0  Real Bed            moderate          True  ...  33.871549
# 74108        1.0  Real Bed            moderate          True  ...  40.706749
# 74109        1.0  Real Bed              strict          True  ...  40.738535
# 74110        1.0  Real Bed            moderate         False  ...  33.761096
#
#         longitude                                        name  \
# 0      -73.991617              Beautiful brownstone 1-bedroom
# 1      -73.989040    Superb 3BR Apt Located Near Times Square
# 2      -73.943756                            The Garden Oasis
# 3     -122.431619          Beautiful Flat in the Heart of SF!
# 4      -77.034596                  Great studio in midtown DC
# ...           ...                                         ...
# 74106  -73.939405                           one room bushwick
# 74107 -118.396053                Spacious Hermosa 2 BR on PCH
# 74108  -73.942377  Modern 2 Bedroom Apartment in Williamsburg
# 74109  -74.000157        Designer's Apartment in HEART of NYC
# 74110 -118.192409              Cozy Boat at Shoreline Village
#
#           neighbourhood number_of_reviews review_scores_rating  \
# 0      Brooklyn Heights                 2                100.0
# 1        Hell's Kitchen                 6                 93.0
# 2                Harlem                10                 92.0
# 3          Lower Haight                 0                  NaN
# 4      Columbia Heights                 4                 40.0
# ...                 ...               ...                  ...
# 74106      Williamsburg                 0                  NaN
# 74107     Hermosa Beach                16                 93.0
# 74108      Williamsburg                43                 94.0
# 74109      West Village                 0                  NaN
# 74110        Long Beach               205                 96.0
#
#                                            thumbnail_url  zipcode bedrooms  \
# 0      https://a0.muscache.com/im/pictures/6d7cbbf7-c...    11201      1.0
# 1      https://a0.muscache.com/im/pictures/348a55fe-4...    10019      3.0
# 2      https://a0.muscache.com/im/pictures/6fae5362-9...    10027      1.0
# 3      https://a0.muscache.com/im/pictures/72208dad-9...  94117.0      2.0
# 4                                                    NaN    20009      0.0
# ...                                                  ...      ...      ...
# 74106  https://a0.muscache.com/im/pictures/55162426/6...  11206.0      1.0
# 74107  https://a0.muscache.com/im/pictures/2b86560b-a...    90254      2.0
# 74108  https://a0.muscache.com/im/pictures/7fbe448c-5...  11206.0      2.0
# 74109  https://a0.muscache.com/im/pictures/b3971b63-0...    10011      0.0
# 74110  https://a0.muscache.com/im/pictures/22968537/d...    90802      1.0
#
#        beds
# 0       1.0
# 1       3.0
# 2       3.0
# 3       2.0
# 4       1.0
# ...     ...
# 74106   1.0
# 74107   4.0
# 74108   2.0
# 74109   2.0
# 74110   2.0
#
# [74111 rows x 29 columns]

# %%
df.shape
# Out:
# (74111, 29)

# %%
df.columns
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id     log_price  accommodates     bathrooms      latitude  \
# count  7.411100e+04  74111.000000  74111.000000  73911.000000  74111.000000
# mean   1.126662e+07      4.782069      3.155146      1.235263     38.445958
# std    6.081735e+06      0.717394      2.153589      0.582044      3.080167
# min    3.440000e+02      0.000000      1.000000      0.000000     33.338905
# 25%    6.261964e+06      4.317488      2.000000      1.000000     34.127908
# 50%    1.225415e+07      4.709530      2.000000      1.000000     40.662138
# 75%    1.640226e+07      5.220356      4.000000      1.000000     40.746096
# max    2.123090e+07      7.600402     16.000000      8.000000     42.390437
#
#           longitude  number_of_reviews  review_scores_rating      bedrooms  \
# count  74111.000000       74111.000000          57389.000000  74020.000000
# mean     -92.397525          20.900568             94.067365      1.265793
# std       21.705322          37.828641              7.836556      0.852143
# min     -122.511500           0.000000             20.000000      0.000000
# 25%     -118.342374           1.000000             92.000000      1.000000
# 50%      -76.996965           6.000000             96.000000      1.000000
# 75%      -73.954660          23.000000            100.000000      1.000000
# max      -70.985047         605.000000            100.000000     10.000000
#
#                beds
# count  73980.000000
# mean       1.710868
# std        1.254142
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       18.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      74111 non-null  int64
#  1   log_price               74111 non-null  float64
#  2   property_type           74111 non-null  object
#  3   room_type               74111 non-null  object
#  4   amenities               74111 non-null  object
#  5   accommodates            74111 non-null  int64
#  6   bathrooms               73911 non-null  float64
#  7   bed_type                74111 non-null  object
#  8   cancellation_policy     74111 non-null  object
#  9   cleaning_fee            74111 non-null  bool
#  10  city                    74111 non-null  object
#  11  description             74111 non-null  object
#  12  first_review            58247 non-null  object
#  13  host_has_profile_pic    73923 non-null  object
#  14  host_identity_verified  73923 non-null  object
#  15  host_response_rate      55812 non-null  object
#  16  host_since              73923 non-null  object
#  17  instant_bookable        74111 non-null  object
#  18  last_review             58284 non-null  object
#  19  latitude                74111 non-null  float64
#  20  longitude               74111 non-null  float64
#  21  name                    74111 non-null  object
#  22  neighbourhood           67239 non-null  object
#  23  number_of_reviews       74111 non-null  int64
#  24  review_scores_rating    57389 non-null  float64
#  25  thumbnail_url           65895 non-null  object
#  26  zipcode                 73145 non-null  object
#  27  bedrooms                74020 non-null  float64
#  28  beds                    73980 non-null  float64
# dtypes: bool(1), float64(7), int64(3), object(18)
# memory usage: 15.9+ MB

# %%
df.dtypes
# Out:
# id                          int64
# log_price                 float64
# property_type              object
# room_type                  object
# amenities                  object
# accommodates                int64
# bathrooms                 float64
# bed_type                   object
# cancellation_policy        object
# cleaning_fee                 bool
# city                       object
# description                object
# first_review               object
# host_has_profile_pic       object
# host_identity_verified     object
# host_response_rate         object
# host_since                 object
# instant_bookable           object
# last_review                object
# latitude                  float64
# longitude                 float64
# name                       object
# neighbourhood              object
# number_of_reviews           int64
# review_scores_rating      float64
# thumbnail_url              object
# zipcode                    object
# bedrooms                  float64
# beds                      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                            0
# log_price                     0
# property_type                 0
# room_type                     0
# amenities                     0
# accommodates                  0
# bathrooms                   200
# bed_type                      0
# cancellation_policy           0
# cleaning_fee                  0
# city                          0
# description                   0
# first_review              15864
# host_has_profile_pic        188
# host_identity_verified      188
# host_response_rate        18299
# host_since                  188
# instant_bookable              0
# last_review               15827
# latitude                      0
# longitude                     0
# name                          0
# neighbourhood              6872
# number_of_reviews             0
# review_scores_rating      16722
# thumbnail_url              8216
# zipcode                     966
# bedrooms                     91
# beds                        131
# dtype: int64

# %%
df["zipcode"].unique
# Out:
# <bound method Series.unique of 0          11201
# 1          10019
# 2          10027
# 3        94117.0
# 4          20009
#           ...
# 74106    11206.0
# 74107      90254
# 74108    11206.0
# 74109      10011
# 74110      90802
# Name: zipcode, Length: 74111, dtype: object>

# %%
index= ["host_response_rate","property_type", "room_type","accommodates","bathrooms","bed_type", "cancellation_policy", "cleaning_fee",
       "city","instant_bookable", "beds", "bedrooms", "neighbourhood","first_review", "last_review","zipcode",
       "name","host_since","thumbnail_url", "latitude", "longitude", 
        "host_has_profile_pic", "host_identity_verified"]

for i in index:
    
    print(df[i].value_counts(), "\n")
    print("---------------------------------------------------------------")
# Out:
# host_response_rate
# 100%    43254
# 90%      2277
# 80%      1113
# 0%        883
# 50%       611
#         ...
# 39%         1
# 23%         1
# 15%         1
# 31%         1
# 21%         1
# Name: count, Length: 80, dtype: int64
#
# ---------------------------------------------------------------
# property_type
# Apartment             49003
# House                 16511
# Condominium            2658
# Townhouse              1692
# Loft                   1244
# Other                   607
# Guesthouse              498
# Bed & Breakfast         462
# Bungalow                366
# Villa                   179
# Dorm                    142
# Guest suite             123
# Camper/RV                94
# Timeshare                77
# Cabin                    72
# In-law                   71
# Hostel                   70
# Boutique hotel           69
# Boat                     65
# Serviced apartment       21
# Tent                     18
# Castle                   13
# Vacation home            11
# Yurt                      9
# Hut                       8
# Treehouse                 7
# Chalet                    6
# Earth House               4
# Tipi                      3
# Cave                      2
# Train                     2
# Casa particular           1
# Parking Space             1
# Lighthouse                1
# Island                    1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# room_type
# Entire home/apt    41310
# Private room       30638
# Shared room         2163
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# accommodates
# 2     31854
# 4     12066
# 1      9434
# 3      7794
# 6      4969
# 5      3444
# 8      1795
# 7       946
# 10      701
# 16      301
# 9       270
# 12      264
# 14      104
# 11       79
# 15       54
# 13       36
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# bathrooms
# 1.0    58099
# 2.0     7936
# 1.5     3801
# 2.5     1567
# 3.0     1066
# 3.5      429
# 4.0      286
# 0.5      209
# 0.0      198
# 4.5      116
# 5.0       72
# 8.0       41
# 5.5       39
# 6.0       24
# 6.5       12
# 7.0       10
# 7.5        6
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# bed_type
# Real Bed         72028
# Futon              753
# Pull-out Sofa      585
# Airbed             477
# Couch              268
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# cancellation_policy
# strict             32374
# flexible           22545
# moderate           19063
# super_strict_30      112
# super_strict_60       17
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# cleaning_fee
# True     54403
# False    19708
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# city
# NYC        32349
# LA         22453
# SF          6434
# DC          5688
# Chicago     3719
# Boston      3468
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# instant_bookable
# f    54660
# t    19451
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# beds
# 1.0     45144
# 2.0     16704
# 3.0      6442
# 4.0      3065
# 5.0      1287
# 6.0       661
# 7.0       216
# 8.0       186
# 10.0       88
# 9.0        72
# 16.0       38
# 12.0       29
# 11.0       23
# 13.0       10
# 15.0        6
# 14.0        4
# 0.0         4
# 18.0        1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# bedrooms
# 1.0     49784
# 2.0     11351
# 0.0      6715
# 3.0      4309
# 4.0      1330
# 5.0       355
# 6.0       106
# 7.0        38
# 8.0        14
# 10.0       10
# 9.0         8
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# neighbourhood
# Williamsburg                2862
# Bedford-Stuyvesant          2166
# Bushwick                    1601
# Upper West Side             1396
# Mid-Wilshire                1392
#                             ...
# Todt Hill                      1
# Suitland-Silver Hill, MD       1
# Irwindale                      1
# Rolling Hills                  1
# Grant City                     1
# Name: count, Length: 619, dtype: int64
#
# ---------------------------------------------------------------
# first_review
# 2017-01-01    293
# 2017-01-22    249
# 2016-01-02    221
# 2017-01-02    211
# 2017-09-04    193
#              ...
# 2012-11-29      1
# 2009-09-03      1
# 2012-01-28      1
# 2011-12-30      1
# 2010-08-18      1
# Name: count, Length: 2554, dtype: int64
#
# ---------------------------------------------------------------
# last_review
# 2017-04-30    1344
# 2017-09-24    1278
# 2017-09-17    1215
# 2017-04-23    1025
# 2017-09-18     832
#               ...
# 2014-12-20       1
# 2013-10-16       1
# 2013-06-25       1
# 2015-02-22       1
# 2012-12-12       1
# Name: count, Length: 1371, dtype: int64
#
# ---------------------------------------------------------------
# zipcode
# 11211.0       1368
# 90291         1274
# 11221         1188
# 94110          988
# 90046          967
#               ...
# 10129            1
# 11377.0          1
# 10002-2289       1
# 92821            1
# 10012.0          1
# Name: count, Length: 769, dtype: int64
#
# ---------------------------------------------------------------
# name
# Bunk bed in the Treat Street Clubhouse                8
# East Village Studio                                   7
# Your home away from home                              7
# Cozy Private Room                                     6
# Spacious Private Room in Brooklyn                     6
#                                                      ..
# BEAUTIFUL Mediterranean STyle House                   1
# 1 Bedroom (Queen) Mins From JFK and Casino            1
# Amazing 2-BR Apt in Old Town! Eat,Drink,Beach&Shop    1
# Full Rowhouse w/Patio & Balcony                       1
# No.7 Queen Size Cozy Room 舒适大床房                       1
# Name: count, Length: 73359, dtype: int64
#
# ---------------------------------------------------------------
# host_since
# 2015-03-30    246
# 2014-02-14    173
# 2016-09-16     83
# 2015-05-18     83
# 2015-07-06     82
#              ...
# 2009-06-05      1
# 2009-07-18      1
# 2008-03-03      1
# 2010-04-30      1
# 2009-08-23      1
# Name: count, Length: 3087, dtype: int64
#
# ---------------------------------------------------------------
# thumbnail_url
# https://a0.muscache.com/im/pictures/70087089/bc66229a_original.jpg?aki_policy=small              3
# https://a0.muscache.com/im/pictures/4491e5c5-33f6-4704-9887-76a059f86fda.jpg?aki_policy=small    2
# https://a0.muscache.com/im/pictures/28563531/1000de61_original.jpg?aki_policy=small              2
# https://a0.muscache.com/im/pictures/105275678/2ec252ae_original.jpg?aki_policy=small             2
# https://a0.muscache.com/im/pictures/23033013/54d62516_original.jpg?aki_policy=small              2
#                                                                                                 ..
# https://a0.muscache.com/im/pictures/751551d4-3a22-4f84-a14f-c04811d3fd7e.jpg?aki_policy=small    1
# https://a0.muscache.com/im/pictures/8ba850b8-7c00-44be-a8d3-8c640995b002.jpg?aki_policy=small    1
# https://a0.muscache.com/im/pictures/1a2878c7-7707-49e4-8342-d71dcc45794b.jpg?aki_policy=small    1
# https://a0.muscache.com/im/pictures/5d56c2fa-8e34-4c04-b0a9-bbb5a8dbec19.jpg?aki_policy=small    1
# https://a0.muscache.com/im/pictures/348a55fe-4b65-452a-b48a-bfecb3b58a66.jpg?aki_policy=small    1
# Name: count, Length: 65883, dtype: int64
#
# ---------------------------------------------------------------
# latitude
# 33.761096    1
# 40.696524    1
# 40.766115    1
# 40.808110    1
# 37.772004    1
#             ..
# 40.643773    1
# 40.719086    1
# 42.339194    1
# 41.910308    1
# 41.908240    1
# Name: count, Length: 74111, dtype: int64
#
# ---------------------------------------------------------------
# longitude
# -118.192409    1
# -73.991617     1
# -73.989040     1
# -73.943756     1
# -122.431619    1
#               ..
# -73.950855     1
# -73.990285     1
# -71.049672     1
# -87.675261     1
# -87.695242     1
# Name: count, Length: 74111, dtype: int64
#
# ---------------------------------------------------------------
# host_has_profile_pic
# t    73697
# f      226
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# host_identity_verified
# t    49748
# f    24175
# Name: count, dtype: int64
#
# ---------------------------------------------------------------

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# # Handling Missing Values

# %%
for column in df.columns:
    
    if df[column].isnull().sum() != 0:
        
        print("========================================")
        print("\n{} :- {},  dtypes : {}".format(column,df[column].isnull().sum(),df[column].dtypes))
# Out:
# ========================================
#
# bathrooms :- 200,  dtypes : float64
# ========================================
#
# first_review :- 15864,  dtypes : object
# ========================================
#
# host_has_profile_pic :- 188,  dtypes : object
# ========================================
#
# host_identity_verified :- 188,  dtypes : object
# ========================================
#
# host_response_rate :- 18299,  dtypes : object
# ========================================
#
# host_since :- 188,  dtypes : object
# ========================================
#
# last_review :- 15827,  dtypes : object
# ========================================
#
# neighbourhood :- 6872,  dtypes : object
# ========================================
#
# review_scores_rating :- 16722,  dtypes : float64
# ========================================
#
# thumbnail_url :- 8216,  dtypes : object
# ========================================
#
# zipcode :- 966,  dtypes : object
# ========================================
#
# bedrooms :- 91,  dtypes : float64
# ========================================
#
# beds :- 131,  dtypes : float64

# %% [markdown]
# Last Review

# %%
df.last_review.fillna(method="ffill",inplace=True)

# %% [markdown]
# First Review

# %%
df.first_review.fillna(method="ffill",inplace=True)

# %% [markdown]
# Host Since

# %%
df.host_since.fillna(method="ffill",inplace=True)

# %% [markdown]
# Bathrooms

# %%
sns.distplot(df["bathrooms"])
# Out:
# <Axes: xlabel='bathrooms', ylabel='Density'>

# %%
df["bathrooms"] = df['bathrooms'].fillna(round(df["bathrooms"].median()))

# %% [markdown]
# Review_Scores_Rating

# %%
sns.distplot(df["review_scores_rating"])
# Out:
# <Axes: xlabel='review_scores_rating', ylabel='Density'>

# %%
df["review_scores_rating"] = df["review_scores_rating"].fillna(0)

# %% [markdown]
# Bedrooms

# %%
sns.distplot(df["bedrooms"])
plt.show()

# %%
df["bedrooms"] = df['bedrooms'].fillna((df["bathrooms"].median()))

# %% [markdown]
# Beds

# %%
sns.distplot(df["beds"])
plt.show()

# %%
df["beds"] = df["beds"].fillna((df["bathrooms"].median()))

# %% [markdown]
# Amenties

# %%
amenities_count = []
for i in df["amenities"]:
    amenities_count.append(len(i))
    
df["amenities"] = amenities_count

# %% [markdown]
# # Data Visualisation

# %%
# Function to plot catplot graphs
def plot_catplot(h,v,he,a):
    sns.set(font_scale=1.5)
    sns.catplot(x=h,kind=v,data=df,height=he, aspect = a)
    
# Function to plot catplot graphs
def plot_piechart(h):
    sns.set(font_scale=1.5)
    fig = plt.figure(figsize=(5,5))
    ax = fig.add_axes([0,0,1,1])
    ax.axis('equal')
    langs = list(df[h].unique())
    students =list(df[h].value_counts())
    ax.pie(students, labels = langs,autopct='%1.2f%%')
    plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.distplot(df["log_price"])
plt.title('Price distribution')
plt.show()

# %%
plot_catplot("room_type", "count", 5, 2)

# %%
plot_piechart("room_type")

# %%
plot_catplot("city","count", 5, 2)

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = list(df.city.unique())
students =list(df.city.value_counts())
ax.pie(students, labels = langs,autopct='%1.2f%%')
plt.show()

# %%
data = df.neighbourhood.value_counts()[:15]
plt.figure(figsize=(22,22))
x = list(data.index)
y = list(data.values)
x.reverse()
y.reverse()

plt.title("Most popular Neighbourhood")
plt.ylabel("Neighbourhood Area")
plt.xlabel("Number of guest who host in this area")

plt.barh(x,y)
plt.show()

# %%
plot_catplot("cancellation_policy","count",10, 2)

# %%
plot_catplot("cleaning_fee","count",6,2)

# %%
def plot_violinplot(h,v):
    plt.figure(figsize=(15,8))
    sns.set(font_scale=1.5)
    sns.violinplot(data=df, x=h, y=v, palette='GnBu_d')
    plt.title('Density and distribution of prices ', fontsize=15)
    plt.xlabel(h)
    plt.ylabel(v)

# %%
plot_violinplot("city","log_price")

# %%
plot_violinplot("room_type","log_price")

# %%
plot_violinplot("cancellation_policy","log_price")

# %%
plot_violinplot("bed_type","log_price")

# %%
plot_catplot("bed_type","count",8, 2)

# %%
categorical_col = []
numerical_col = []
for column in df.columns:
    
    if df[column].dtypes != "float64" and df[column].dtypes != "int64":
        categorical_col.append(column)
    else:
        numerical_col.append(column)

# %%
numerical_col
# Out:
# ['id',
#  'log_price',
#  'amenities',
#  'accommodates',
#  'bathrooms',
#  'latitude',
#  'longitude',
#  'number_of_reviews',
#  'review_scores_rating',
#  'bedrooms',
#  'beds']

# %%
categorical_col
# Out:
# ['property_type',
#  'room_type',
#  'bed_type',
#  'cancellation_policy',
#  'cleaning_fee',
#  'city',
#  'description',
#  'first_review',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'host_response_rate',
#  'host_since',
#  'instant_bookable',
#  'last_review',
#  'name',
#  'neighbourhood',
#  'thumbnail_url',
#  'zipcode']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for col in categorical_col:
    df[col] = le.fit_transform(df[col])

# %%
pd.set_option("display.max_columns",None)
df
# Out:
#              id  log_price  property_type  room_type  amenities  accommodates  \
# 0       6901257   5.010635              0          0        152             3
# 1       6304928   5.129899              0          0        218             7
# 2       7919400   4.976734              0          0        311             5
# 3      13418779   6.620073             17          0        210             4
# 4       3808709   4.744932              0          0        174             2
# ...         ...        ...            ...        ...        ...           ...
# 74106  14549287   4.605170              0          1          2             1
# 74107  13281809   5.043425              0          0        224             4
# 74108  18688039   5.220356              0          0        402             5
# 74109  17045948   5.273000              0          0        189             2
# 74110   3534845   4.852030              2          0        279             4
#
#        bathrooms  bed_type  cancellation_policy  cleaning_fee  city  \
# 0            1.0         4                    2             1     4
# 1            1.0         4                    2             1     4
# 2            1.0         4                    1             1     4
# 3            1.0         4                    0             1     5
# 4            1.0         4                    1             1     2
# ...          ...       ...                  ...           ...   ...
# 74106        1.0         4                    0             0     4
# 74107        2.0         4                    1             1     3
# 74108        1.0         4                    1             1     4
# 74109        1.0         4                    2             1     4
# 74110        1.0         4                    1             0     3
#
#        description  first_review  host_has_profile_pic  \
# 0             9972          2079                     1
# 1            19019          2492                     1
# 2            55642          2395                     1
# 3            63089          2395                     1
# 4            15914          1676                     1
# ...            ...           ...                   ...
# 74106        72523          1994                     1
# 74107        30741          2137                     1
# 74108         4691          1547                     1
# 74109        21026          1547                     1
# 74110        71303          1064                     1
#
#        host_identity_verified  host_response_rate  host_since  \
# 0                           1                  80        1069
# 1                           0                   2        2980
# 2                           1                   2        2743
# 3                           1                  80        2188
# 4                           1                   2        2139
# ...                       ...                 ...         ...
# 74106                       1                  80        1432
# 74107                       0                   2        2568
# 74108                       1                   2         988
# 74109                       0                   2        3070
# 74110                       1                   2        1314
#
#        instant_bookable  last_review   latitude   longitude   name  \
# 0                     0          926  40.696524  -73.991617  10464
# 1                     1         1358  40.766115  -73.989040  65672
# 2                     1         1349  40.808110  -73.943756  66396
# 3                     0         1349  37.772004 -122.431619   9387
# 4                     1         1114  38.925627  -77.034596  32068
# ...                 ...          ...        ...         ...    ...
# 74106                 0         1142  40.709025  -73.939405  72348
# 74107                 0         1197  33.871549 -118.396053  59902
# 74108                 1         1345  40.706749  -73.942377  43692
# 74109                 1         1345  40.738535  -74.000157  26450
# 74110                 0         1212  33.761096 -118.192409  22195
#
#        neighbourhood  number_of_reviews  review_scores_rating  thumbnail_url  \
# 0                 77                  2                 100.0          32398
# 1                252                  6                  93.0          16220
# 2                247                 10                  92.0          32852
# 3                325                  0                   0.0          33692
# 4                119                  4                  40.0          65883
# ...              ...                ...                   ...            ...
# 74106            605                  0                   0.0          25229
# 74107            255                 16                  93.0          13695
# 74108            605                 43                  94.0          37484
# 74109            592                  0                   0.0          51019
# 74110            319                205                  96.0          10902
#
#        zipcode  bedrooms  beds
# 0          195       1.0   1.0
# 1           74       3.0   3.0
# 2           84       1.0   3.0
# 3          748       2.0   2.0
# 4          341       0.0   1.0
# ...        ...       ...   ...
# 74106      203       1.0   1.0
# 74107      515       2.0   4.0
# 74108      203       2.0   2.0
# 74109       61       0.0   2.0
# 74110      577       1.0   2.0
#
# [74111 rows x 29 columns]

# %% [markdown]
# # HeatMap

# %%
plt.figure(figsize = (40,40))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="seismic")
plt.show()

# %%
x = df.drop(["id","name","log_price","description","first_review","host_since","last_review","neighbourhood",
            "thumbnail_url", "zipcode"],axis = 1)
y = df.log_price

# %%
x
# Out:
#        property_type  room_type  amenities  accommodates  bathrooms  bed_type  \
# 0                  0          0        152             3        1.0         4
# 1                  0          0        218             7        1.0         4
# 2                  0          0        311             5        1.0         4
# 3                 17          0        210             4        1.0         4
# 4                  0          0        174             2        1.0         4
# ...              ...        ...        ...           ...        ...       ...
# 74106              0          1          2             1        1.0         4
# 74107              0          0        224             4        2.0         4
# 74108              0          0        402             5        1.0         4
# 74109              0          0        189             2        1.0         4
# 74110              2          0        279             4        1.0         4
#
#        cancellation_policy  cleaning_fee  city  host_has_profile_pic  \
# 0                        2             1     4                     1
# 1                        2             1     4                     1
# 2                        1             1     4                     1
# 3                        0             1     5                     1
# 4                        1             1     2                     1
# ...                    ...           ...   ...                   ...
# 74106                    0             0     4                     1
# 74107                    1             1     3                     1
# 74108                    1             1     4                     1
# 74109                    2             1     4                     1
# 74110                    1             0     3                     1
#
#        host_identity_verified  host_response_rate  instant_bookable  \
# 0                           1                  80                 0
# 1                           0                   2                 1
# 2                           1                   2                 1
# 3                           1                  80                 0
# 4                           1                   2                 1
# ...                       ...                 ...               ...
# 74106                       1                  80                 0
# 74107                       0                   2                 0
# 74108                       1                   2                 1
# 74109                       0                   2                 1
# 74110                       1                   2                 0
#
#         latitude   longitude  number_of_reviews  review_scores_rating  \
# 0      40.696524  -73.991617                  2                 100.0
# 1      40.766115  -73.989040                  6                  93.0
# 2      40.808110  -73.943756                 10                  92.0
# 3      37.772004 -122.431619                  0                   0.0
# 4      38.925627  -77.034596                  4                  40.0
# ...          ...         ...                ...                   ...
# 74106  40.709025  -73.939405                  0                   0.0
# 74107  33.871549 -118.396053                 16                  93.0
# 74108  40.706749  -73.942377                 43                  94.0
# 74109  40.738535  -74.000157                  0                   0.0
# 74110  33.761096 -118.192409                205                  96.0
#
#        bedrooms  beds
# 0           1.0   1.0
# 1           3.0   3.0
# 2           1.0   3.0
# 3           2.0   2.0
# 4           0.0   1.0
# ...         ...   ...
# 74106       1.0   1.0
# 74107       2.0   4.0
# 74108       2.0   2.0
# 74109       0.0   2.0
# 74110       1.0   2.0
#
# [74111 rows x 19 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=101)

# %% [markdown]
# ## Model Building

# %% [markdown]
# # Linear Regression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)

y_pred_lr = lr.predict(x_test)

# %%
mae_lr = metrics.mean_absolute_error(y_test, y_pred_lr)
mse_lr = metrics.mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_lr))
r2_lr = metrics.r2_score(y_test, y_pred_lr)


print('\nMean Absolute Error of Linear Regression     : ', mae_lr)
print('\nMean Squarred Error of Linear Regression     : ', mse_lr)
print('\nRoot Mean Squarred Error of Linear Regression: ', rmse_lr)
print('\nR2 Score of Linear Regression                : ', r2_lr)
# Out:
# Mean Absolute Error of Linear Regression     :  0.36870444242179246
#
# Mean Squarred Error of Linear Regression     :  0.23465903965420434
#
# Root Mean Squarred Error of Linear Regression:  0.48441618434379785
#
# R2 Score of Linear Regression                :  0.5468814426508137

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)

y_pred_rf = rf.predict(x_test)

# %%
mae_rf = metrics.mean_absolute_error(y_test, y_pred_rf)
mse_rf = metrics.mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(metrics.mean_squared_error(y_test, y_pred_rf))
r2_rf = metrics.r2_score(y_test, y_pred_rf)


print('\nMean Absolute Error of Random Forest Regressor     : ', mae_rf)
print('\nMean Squarred Error of Random Forest Regressor     : ', mse_rf)
print('\nRoot Mean Squarred Error of Random Forest Regressor: ', rmse_rf)
print('\nR2 Score of Random Forest Regressor                : ', r2_rf)
# Out:
# Mean Absolute Error of Random Forest Regressor     :  0.2840357092078498
#
# Mean Squarred Error of Random Forest Regressor     :  0.15563088667104663
#
# Root Mean Squarred Error of Random Forest Regressor:  0.3945008069333276
#
# R2 Score of Random Forest Regressor                :  0.6994820955916417

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.linear_model import Ridge
model = Pipeline([
    ('poly', PolynomialFeatures()),
    ('ridge', Ridge(fit_intercept=True))
])

param_grid = {
    'poly__degree': [1, 2, 3],
    'ridge__alpha': [0.1, 0.5, 1.0, 2.0]
}

# Perform grid search with 5-fold cross-validation

poly_tuned = GridSearchCV(model, param_grid, cv=5)

# %%
#Traning and Testing

poly_tuned.fit(x_train, y_train)

y_pred_poly = poly_tuned.predict(x_test)

# %%
mae_poly  = metrics.mean_absolute_error(y_test, y_pred_poly)
mse_poly  = metrics.mean_squared_error(y_test, y_pred_poly)
rmse_poly = np.sqrt(metrics.mean_squared_error(y_test, y_pred_poly))
r2_poly   = metrics.r2_score(y_test, y_pred_poly)


print('\nMean Absolute Error of Polynomial Regression     : ', mae_poly)
print('\nMean Squarred Error of Polynomial Regression     : ', mse_poly)
print('\nRoot Mean Squarred Error of Polynomial Regression: ', rmse_poly)
print('\nR2 Score of Polynomial Regression                : ', r2_poly)
# Out:
# Mean Absolute Error of Polynomial Regression     :  0.342322956671811
#
# Mean Squarred Error of Polynomial Regression     :  0.20385050510331743
#
# Root Mean Squarred Error of Polynomial Regression:  0.45149806766288314
#
# R2 Score of Polynomial Regression                :  0.6063716662122495

# %% [markdown]
# # CatBoost

# %%
model_CBR = CatBoostRegressor()

# %%
model_CBR.fit(x_train, y_train)

cross_val_score(model_CBR, x_train, y_train,
                           scoring='r2',
                           cv=KFold(n_splits=5,
                                    shuffle=True,
                                    random_state=2022,
                                    ))
# Out:
# Learning rate set to 0.078038
# 0:	learn: 0.6884814	total: 151ms	remaining: 2m 30s
# 1:	learn: 0.6629188	total: 178ms	remaining: 1m 28s
# 2:	learn: 0.6397968	total: 212ms	remaining: 1m 10s
# 3:	learn: 0.6197053	total: 242ms	remaining: 1m
# 4:	learn: 0.6022100	total: 270ms	remaining: 53.7s
# 5:	learn: 0.5867609	total: 292ms	remaining: 48.4s
# 6:	learn: 0.5716923	total: 316ms	remaining: 44.8s
# 7:	learn: 0.5592553	total: 337ms	remaining: 41.8s
# 8:	learn: 0.5475392	total: 360ms	remaining: 39.6s
# 9:	learn: 0.5373710	total: 384ms	remaining: 38.1s
# 10:	learn: 0.5274211	total: 414ms	remaining: 37.2s
# 11:	learn: 0.5182308	total: 468ms	remaining: 38.6s
# 12:	learn: 0.5107779	total: 543ms	remaining: 41.2s
# 13:	learn: 0.5038525	total: 587ms	remaining: 41.3s
# 14:	learn: 0.4975683	total: 633ms	remaining: 41.6s
# 15:	learn: 0.4914023	total: 659ms	remaining: 40.5s
# 16:	learn: 0.4865003	total: 683ms	remaining: 39.5s
# 17:	learn: 0.4820088	total: 707ms	remaining: 38.6s
# 205:	learn: 0.3896386	total: 5.31s	remaining: 20.5s
# 206:	learn: 0.3895612	total: 5.34s	remaining: 20.5s
# 207:	learn: 0.3894429	total: 5.37s	remaining: 20.4s
# 208:	learn: 0.3893024	total: 5.39s	remaining: 20.4s
# 209:	learn: 0.3892315	total: 5.41s	remaining: 20.4s
# 210:	learn: 0.3890933	total: 5.44s	remaining: 20.3s
# 211:	learn: 0.3889727	total: 5.46s	remaining: 20.3s
# 212:	learn: 0.3888080	total: 5.48s	remaining: 20.3s
# 213:	learn: 0.3886636	total: 5.51s	remaining: 20.2s
# 214:	learn: 0.3885393	total: 5.54s	remaining: 20.2s
# 215:	learn: 0.3884435	total: 5.57s	remaining: 20.2s
# 216:	learn: 0.3883755	total: 5.59s	remaining: 20.2s
# 217:	learn: 0.3882930	total: 5.61s	remaining: 20.1s
# 218:	learn: 0.3881561	total: 5.63s	remaining: 20.1s
# 219:	learn: 0.3880968	total: 5.66s	remaining: 20s
# 220:	learn: 0.3879666	total: 5.68s	remaining: 20s
# 221:	learn: 0.3878864	total: 5.7s	remaining: 20s
# 222:	learn: 0.3878149	total: 5.72s	remaining: 19.9s
# 223:	learn: 0.3877238	total: 5.74s	remaining: 19.9s
# 224:	learn: 0.3876419	total: 5.77s	remaining: 19.9s
# 225:	learn: 0.3875306	total: 5.8s	remaining: 19.9s
# 226:	learn: 0.3874504	total: 5.82s	remaining: 19.8s
# 227:	learn: 0.3873421	total: 5.85s	remaining: 19.8s
# 228:	learn: 0.3872726	total: 5.87s	remaining: 19.8s
# 229:	learn: 0.3871639	total: 5.89s	remaining: 19.7s
# 230:	learn: 0.3871191	total: 5.92s	remaining: 19.7s
# 231:	learn: 0.3870086	total: 5.94s	remaining: 19.7s
# 232:	learn: 0.3869472	total: 5.96s	remaining: 19.6s
# 233:	learn: 0.3868441	total: 5.99s	remaining: 19.6s
# 234:	learn: 0.3867951	total: 6.01s	remaining: 19.6s
# 235:	learn: 0.3866960	total: 6.03s	remaining: 19.5s
# 236:	learn: 0.3865926	total: 6.06s	remaining: 19.5s
# 237:	learn: 0.3865089	total: 6.08s	remaining: 19.5s
# 238:	learn: 0.3864080	total: 6.1s	remaining: 19.4s
# 239:	learn: 0.3863205	total: 6.13s	remaining: 19.4s
# 240:	learn: 0.3862568	total: 6.15s	remaining: 19.4s
# 241:	learn: 0.3861786	total: 6.18s	remaining: 19.3s
# 242:	learn: 0.3861073	total: 6.2s	remaining: 19.3s
# 243:	learn: 0.3860677	total: 6.22s	remaining: 19.3s
# 244:	learn: 0.3860199	total: 6.24s	remaining: 19.2s
# 245:	learn: 0.3859325	total: 6.27s	remaining: 19.2s
# 246:	learn: 0.3858155	total: 6.3s	remaining: 19.2s
# 247:	learn: 0.3857126	total: 6.32s	remaining: 19.2s
# 248:	learn: 0.3856662	total: 6.35s	remaining: 19.1s
# 249:	learn: 0.3855687	total: 6.37s	remaining: 19.1s
# 250:	learn: 0.3855020	total: 6.4s	remaining: 19.1s
# 251:	learn: 0.3854354	total: 6.43s	remaining: 19.1s
# 392:	learn: 0.3762826	total: 10.1s	remaining: 15.6s
# 393:	learn: 0.3762213	total: 10.1s	remaining: 15.6s
# 394:	learn: 0.3761705	total: 10.2s	remaining: 15.6s
# 395:	learn: 0.3761362	total: 10.2s	remaining: 15.6s
# 396:	learn: 0.3761015	total: 10.2s	remaining: 15.6s
# 397:	learn: 0.3760325	total: 10.3s	remaining: 15.5s
# 398:	learn: 0.3759877	total: 10.3s	remaining: 15.5s
# 399:	learn: 0.3759484	total: 10.3s	remaining: 15.5s
# 400:	learn: 0.3759183	total: 10.4s	remaining: 15.5s
# 401:	learn: 0.3758792	total: 10.4s	remaining: 15.5s
# 402:	learn: 0.3757791	total: 10.4s	remaining: 15.5s
# 403:	learn: 0.3757507	total: 10.5s	remaining: 15.4s
# 404:	learn: 0.3757138	total: 10.5s	remaining: 15.4s
# 405:	learn: 0.3756341	total: 10.5s	remaining: 15.4s
# 406:	learn: 0.3755833	total: 10.5s	remaining: 15.4s
# 407:	learn: 0.3755534	total: 10.6s	remaining: 15.3s
# 408:	learn: 0.3755135	total: 10.6s	remaining: 15.3s
# 409:	learn: 0.3754637	total: 10.6s	remaining: 15.3s
# 410:	learn: 0.3754033	total: 10.7s	remaining: 15.3s
# 411:	learn: 0.3753801	total: 10.7s	remaining: 15.3s
# 412:	learn: 0.3753405	total: 10.7s	remaining: 15.2s
# 413:	learn: 0.3752750	total: 10.7s	remaining: 15.2s
# 414:	learn: 0.3752416	total: 10.8s	remaining: 15.2s
# 415:	learn: 0.3752081	total: 10.8s	remaining: 15.2s
# 416:	learn: 0.3751408	total: 10.8s	remaining: 15.2s
# 417:	learn: 0.3750905	total: 10.9s	remaining: 15.1s
# 418:	learn: 0.3750356	total: 10.9s	remaining: 15.1s
# 419:	learn: 0.3749871	total: 10.9s	remaining: 15.1s
# 420:	learn: 0.3749557	total: 11s	remaining: 15.1s
# 421:	learn: 0.3748654	total: 11s	remaining: 15s
# 422:	learn: 0.3748330	total: 11s	remaining: 15s
# 423:	learn: 0.3748027	total: 11s	remaining: 15s
# 424:	learn: 0.3747372	total: 11.1s	remaining: 15s
# 425:	learn: 0.3747014	total: 11.1s	remaining: 14.9s
# 426:	learn: 0.3746370	total: 11.1s	remaining: 14.9s
# 427:	learn: 0.3745990	total: 11.1s	remaining: 14.9s
# 428:	learn: 0.3745633	total: 11.2s	remaining: 14.9s
# 429:	learn: 0.3745272	total: 11.2s	remaining: 14.8s
# 430:	learn: 0.3744988	total: 11.2s	remaining: 14.8s
# 431:	learn: 0.3744776	total: 11.3s	remaining: 14.8s
# 432:	learn: 0.3744222	total: 11.3s	remaining: 14.8s
# 433:	learn: 0.3743823	total: 11.3s	remaining: 14.8s
# 434:	learn: 0.3743548	total: 11.3s	remaining: 14.7s
# 435:	learn: 0.3743240	total: 11.4s	remaining: 14.7s
# 436:	learn: 0.3742605	total: 11.4s	remaining: 14.7s
# 437:	learn: 0.3741926	total: 11.4s	remaining: 14.6s
# 438:	learn: 0.3741542	total: 11.4s	remaining: 14.6s
# 626:	learn: 0.3667608	total: 15.9s	remaining: 9.48s
# 627:	learn: 0.3667158	total: 16s	remaining: 9.46s
# 628:	learn: 0.3666936	total: 16s	remaining: 9.44s
# 629:	learn: 0.3666718	total: 16s	remaining: 9.41s
# 630:	learn: 0.3666449	total: 16s	remaining: 9.38s
# 631:	learn: 0.3665969	total: 16.1s	remaining: 9.35s
# 632:	learn: 0.3665543	total: 16.1s	remaining: 9.32s
# 633:	learn: 0.3665247	total: 16.1s	remaining: 9.3s
# 634:	learn: 0.3664948	total: 16.1s	remaining: 9.27s
# 635:	learn: 0.3664535	total: 16.1s	remaining: 9.24s
# 636:	learn: 0.3664356	total: 16.2s	remaining: 9.21s
# 637:	learn: 0.3664077	total: 16.2s	remaining: 9.18s
# 638:	learn: 0.3663856	total: 16.2s	remaining: 9.16s
# 639:	learn: 0.3663412	total: 16.2s	remaining: 9.13s
# 640:	learn: 0.3663039	total: 16.2s	remaining: 9.1s
# 641:	learn: 0.3662728	total: 16.3s	remaining: 9.07s
# 642:	learn: 0.3662451	total: 16.3s	remaining: 9.04s
# 643:	learn: 0.3662027	total: 16.3s	remaining: 9.02s
# 644:	learn: 0.3661751	total: 16.3s	remaining: 8.99s
# 645:	learn: 0.3661527	total: 16.3s	remaining: 8.96s
# 646:	learn: 0.3661301	total: 16.4s	remaining: 8.93s
# 647:	learn: 0.3660717	total: 16.4s	remaining: 8.9s
# 648:	learn: 0.3660439	total: 16.4s	remaining: 8.88s
# 649:	learn: 0.3660032	total: 16.4s	remaining: 8.85s
# 650:	learn: 0.3659591	total: 16.5s	remaining: 8.82s
# 651:	learn: 0.3659171	total: 16.5s	remaining: 8.79s
# 652:	learn: 0.3658872	total: 16.5s	remaining: 8.77s
# 653:	learn: 0.3658645	total: 16.5s	remaining: 8.74s
# 654:	learn: 0.3658281	total: 16.5s	remaining: 8.71s
# 655:	learn: 0.3657708	total: 16.6s	remaining: 8.68s
# 656:	learn: 0.3657346	total: 16.6s	remaining: 8.66s
# 657:	learn: 0.3657115	total: 16.6s	remaining: 8.63s
# 658:	learn: 0.3656619	total: 16.6s	remaining: 8.6s
# 659:	learn: 0.3656256	total: 16.6s	remaining: 8.58s
# 660:	learn: 0.3655937	total: 16.7s	remaining: 8.55s
# 661:	learn: 0.3655719	total: 16.7s	remaining: 8.53s
# 662:	learn: 0.3655515	total: 16.7s	remaining: 8.5s
# 663:	learn: 0.3655018	total: 16.7s	remaining: 8.47s
# 664:	learn: 0.3654705	total: 16.8s	remaining: 8.44s
# 665:	learn: 0.3654533	total: 16.8s	remaining: 8.41s
# 666:	learn: 0.3654261	total: 16.8s	remaining: 8.39s
# 667:	learn: 0.3654062	total: 16.8s	remaining: 8.36s
# 668:	learn: 0.3653723	total: 16.8s	remaining: 8.34s
# 669:	learn: 0.3653522	total: 16.9s	remaining: 8.31s
# 670:	learn: 0.3653313	total: 16.9s	remaining: 8.28s
# 671:	learn: 0.3652851	total: 16.9s	remaining: 8.26s
# 672:	learn: 0.3652557	total: 16.9s	remaining: 8.23s
# 767:	learn: 0.3622688	total: 19.3s	remaining: 5.83s
# 768:	learn: 0.3622430	total: 19.3s	remaining: 5.8s
# 769:	learn: 0.3622206	total: 19.3s	remaining: 5.78s
# 770:	learn: 0.3621896	total: 19.4s	remaining: 5.75s
# 771:	learn: 0.3621432	total: 19.4s	remaining: 5.72s
# 772:	learn: 0.3621132	total: 19.4s	remaining: 5.7s
# 773:	learn: 0.3620750	total: 19.4s	remaining: 5.68s
# 774:	learn: 0.3620512	total: 19.5s	remaining: 5.65s
# 775:	learn: 0.3620167	total: 19.5s	remaining: 5.63s
# 776:	learn: 0.3619821	total: 19.5s	remaining: 5.6s
# 777:	learn: 0.3619270	total: 19.6s	remaining: 5.58s
# 778:	learn: 0.3618984	total: 19.6s	remaining: 5.55s
# 779:	learn: 0.3618664	total: 19.6s	remaining: 5.53s
# 780:	learn: 0.3618365	total: 19.6s	remaining: 5.51s
# 781:	learn: 0.3618002	total: 19.7s	remaining: 5.48s
# 782:	learn: 0.3617802	total: 19.7s	remaining: 5.46s
# 783:	learn: 0.3617355	total: 19.7s	remaining: 5.43s
# 784:	learn: 0.3617228	total: 19.8s	remaining: 5.41s
# 785:	learn: 0.3616977	total: 19.8s	remaining: 5.38s
# 786:	learn: 0.3616586	total: 19.8s	remaining: 5.36s
# 787:	learn: 0.3616283	total: 19.8s	remaining: 5.33s
# 788:	learn: 0.3616023	total: 19.9s	remaining: 5.31s
# 789:	learn: 0.3615717	total: 19.9s	remaining: 5.29s
# 790:	learn: 0.3615362	total: 19.9s	remaining: 5.26s
# 791:	learn: 0.3615171	total: 19.9s	remaining: 5.23s
# 792:	learn: 0.3614882	total: 19.9s	remaining: 5.21s
# 793:	learn: 0.3614454	total: 20s	remaining: 5.18s
# 794:	learn: 0.3614056	total: 20s	remaining: 5.16s
# 795:	learn: 0.3613936	total: 20s	remaining: 5.13s
# 796:	learn: 0.3613660	total: 20s	remaining: 5.11s
# 797:	learn: 0.3613449	total: 20.1s	remaining: 5.08s
# 798:	learn: 0.3612898	total: 20.1s	remaining: 5.06s
# 799:	learn: 0.3612711	total: 20.1s	remaining: 5.03s
# 800:	learn: 0.3612473	total: 20.1s	remaining: 5s
# 801:	learn: 0.3612124	total: 20.2s	remaining: 4.98s
# 802:	learn: 0.3611956	total: 20.2s	remaining: 4.95s
# 803:	learn: 0.3611730	total: 20.2s	remaining: 4.93s
# 804:	learn: 0.3611325	total: 20.2s	remaining: 4.9s
# 805:	learn: 0.3611041	total: 20.3s	remaining: 4.88s
# 806:	learn: 0.3610951	total: 20.3s	remaining: 4.85s
# 807:	learn: 0.3610609	total: 20.3s	remaining: 4.82s
# 808:	learn: 0.3610204	total: 20.3s	remaining: 4.8s
# 809:	learn: 0.3609945	total: 20.3s	remaining: 4.77s
# 810:	learn: 0.3609485	total: 20.4s	remaining: 4.75s
# 811:	learn: 0.3609222	total: 20.4s	remaining: 4.72s
# 812:	learn: 0.3608889	total: 20.4s	remaining: 4.7s
# 813:	learn: 0.3608510	total: 20.4s	remaining: 4.67s
# 814:	learn: 0.3608325	total: 20.5s	remaining: 4.64s
# 815:	learn: 0.3608120	total: 20.5s	remaining: 4.62s
# 816:	learn: 0.3607909	total: 20.5s	remaining: 4.59s
# 817:	learn: 0.3607614	total: 20.5s	remaining: 4.57s
# 818:	learn: 0.3607463	total: 20.6s	remaining: 4.54s
# 819:	learn: 0.3607115	total: 20.6s	remaining: 4.52s
# 820:	learn: 0.3607008	total: 20.6s	remaining: 4.49s
# 821:	learn: 0.3606814	total: 20.6s	remaining: 4.47s
# 822:	learn: 0.3606606	total: 20.7s	remaining: 4.44s
# 823:	learn: 0.3606351	total: 20.7s	remaining: 4.42s
# 824:	learn: 0.3606238	total: 20.7s	remaining: 4.39s
# 825:	learn: 0.3605791	total: 20.7s	remaining: 4.37s
# 826:	learn: 0.3605589	total: 20.8s	remaining: 4.34s
# 827:	learn: 0.3605062	total: 20.8s	remaining: 4.32s
# 828:	learn: 0.3604800	total: 20.8s	remaining: 4.29s
# 829:	learn: 0.3604585	total: 20.8s	remaining: 4.26s
# 830:	learn: 0.3604291	total: 20.8s	remaining: 4.24s
# 831:	learn: 0.3604054	total: 20.9s	remaining: 4.21s
# 832:	learn: 0.3603877	total: 20.9s	remaining: 4.19s
# 833:	learn: 0.3603588	total: 20.9s	remaining: 4.16s
# 834:	learn: 0.3603460	total: 20.9s	remaining: 4.14s
# 835:	learn: 0.3603055	total: 21s	remaining: 4.11s
# 836:	learn: 0.3602905	total: 21s	remaining: 4.08s
# 837:	learn: 0.3602715	total: 21s	remaining: 4.06s
# 838:	learn: 0.3602403	total: 21s	remaining: 4.03s
# 839:	learn: 0.3602195	total: 21s	remaining: 4.01s
# 840:	learn: 0.3602021	total: 21.1s	remaining: 3.98s
# 841:	learn: 0.3601719	total: 21.1s	remaining: 3.96s
# 842:	learn: 0.3601381	total: 21.1s	remaining: 3.93s
# 843:	learn: 0.3600999	total: 21.1s	remaining: 3.91s
# 844:	learn: 0.3600746	total: 21.2s	remaining: 3.88s
# 845:	learn: 0.3600462	total: 21.2s	remaining: 3.86s
# 846:	learn: 0.3600126	total: 21.2s	remaining: 3.83s
# 847:	learn: 0.3599912	total: 21.2s	remaining: 3.81s
# 848:	learn: 0.3599464	total: 21.3s	remaining: 3.78s
# 849:	learn: 0.3599246	total: 21.3s	remaining: 3.75s
# 850:	learn: 0.3599034	total: 21.3s	remaining: 3.73s
# 851:	learn: 0.3598674	total: 21.3s	remaining: 3.7s
# 852:	learn: 0.3598319	total: 21.3s	remaining: 3.68s
# 853:	learn: 0.3598152	total: 21.4s	remaining: 3.65s
# 854:	learn: 0.3597859	total: 21.4s	remaining: 3.63s
# 855:	learn: 0.3597773	total: 21.4s	remaining: 3.6s
# 856:	learn: 0.3597529	total: 21.4s	remaining: 3.58s
# 857:	learn: 0.3597299	total: 21.4s	remaining: 3.55s
# 858:	learn: 0.3597063	total: 21.5s	remaining: 3.52s
# 859:	learn: 0.3596731	total: 21.5s	remaining: 3.5s
# 716:	learn: 0.3617562	total: 14.3s	remaining: 5.64s
# 717:	learn: 0.3617325	total: 14.3s	remaining: 5.62s
# 718:	learn: 0.3617078	total: 14.3s	remaining: 5.6s
# 719:	learn: 0.3616854	total: 14.4s	remaining: 5.58s
# 720:	learn: 0.3616609	total: 14.4s	remaining: 5.57s
# 721:	learn: 0.3616358	total: 14.4s	remaining: 5.54s
# 722:	learn: 0.3615918	total: 14.4s	remaining: 5.53s
# 723:	learn: 0.3615776	total: 14.4s	remaining: 5.51s
# 724:	learn: 0.3615302	total: 14.5s	remaining: 5.49s
# 725:	learn: 0.3615005	total: 14.5s	remaining: 5.47s
# 726:	learn: 0.3614594	total: 14.5s	remaining: 5.45s
# 727:	learn: 0.3614369	total: 14.5s	remaining: 5.43s
# 728:	learn: 0.3613910	total: 14.6s	remaining: 5.41s
# 729:	learn: 0.3613538	total: 14.6s	remaining: 5.39s
# 730:	learn: 0.3613042	total: 14.6s	remaining: 5.37s
# 731:	learn: 0.3612420	total: 14.6s	remaining: 5.35s
# 732:	learn: 0.3612009	total: 14.6s	remaining: 5.33s
# 733:	learn: 0.3611746	total: 14.7s	remaining: 5.31s
# 734:	learn: 0.3611559	total: 14.7s	remaining: 5.29s
# 735:	learn: 0.3611077	total: 14.7s	remaining: 5.27s
# 736:	learn: 0.3610861	total: 14.7s	remaining: 5.25s
# 737:	learn: 0.3610157	total: 14.7s	remaining: 5.23s
# 738:	learn: 0.3610008	total: 14.8s	remaining: 5.21s
# 739:	learn: 0.3609603	total: 14.8s	remaining: 5.19s
# 740:	learn: 0.3609403	total: 14.8s	remaining: 5.17s
# 741:	learn: 0.3609048	total: 14.8s	remaining: 5.15s
# 742:	learn: 0.3608514	total: 14.8s	remaining: 5.13s
# 743:	learn: 0.3608049	total: 14.9s	remaining: 5.11s
# 744:	learn: 0.3607919	total: 14.9s	remaining: 5.09s
# 745:	learn: 0.3607645	total: 14.9s	remaining: 5.07s
# 746:	learn: 0.3607369	total: 15s	remaining: 5.06s
# 747:	learn: 0.3607228	total: 15s	remaining: 5.04s
# 748:	learn: 0.3606643	total: 15s	remaining: 5.02s
# 749:	learn: 0.3606465	total: 15s	remaining: 5s
# 750:	learn: 0.3606182	total: 15s	remaining: 4.98s
# 751:	learn: 0.3605960	total: 15s	remaining: 4.96s
# 752:	learn: 0.3605542	total: 15.1s	remaining: 4.94s
# 753:	learn: 0.3605029	total: 15.1s	remaining: 4.92s
# 754:	learn: 0.3604748	total: 15.1s	remaining: 4.91s
# 755:	learn: 0.3604594	total: 15.2s	remaining: 4.9s
# 756:	learn: 0.3604488	total: 15.2s	remaining: 4.89s
# 757:	learn: 0.3604114	total: 15.3s	remaining: 4.88s
# 758:	learn: 0.3603964	total: 15.3s	remaining: 4.86s
# 759:	learn: 0.3603486	total: 15.3s	remaining: 4.84s
# 760:	learn: 0.3603072	total: 15.4s	remaining: 4.82s
# 761:	learn: 0.3602492	total: 15.4s	remaining: 4.8s
# 809:	learn: 0.3586814	total: 16.3s	remaining: 3.82s
# 810:	learn: 0.3586581	total: 16.3s	remaining: 3.8s
# 811:	learn: 0.3586160	total: 16.3s	remaining: 3.78s
# 812:	learn: 0.3585734	total: 16.3s	remaining: 3.76s
# 813:	learn: 0.3585171	total: 16.4s	remaining: 3.74s
# 814:	learn: 0.3584992	total: 16.4s	remaining: 3.72s
# 815:	learn: 0.3584638	total: 16.4s	remaining: 3.7s
# 816:	learn: 0.3584234	total: 16.4s	remaining: 3.68s
# 817:	learn: 0.3583959	total: 16.4s	remaining: 3.66s
# 818:	learn: 0.3583589	total: 16.5s	remaining: 3.64s
# 819:	learn: 0.3583145	total: 16.5s	remaining: 3.62s
# 820:	learn: 0.3582590	total: 16.5s	remaining: 3.6s
# 821:	learn: 0.3582305	total: 16.5s	remaining: 3.58s
# 822:	learn: 0.3582103	total: 16.6s	remaining: 3.56s
# 823:	learn: 0.3581943	total: 16.6s	remaining: 3.54s
# 824:	learn: 0.3581508	total: 16.6s	remaining: 3.53s
# 825:	learn: 0.3581388	total: 16.6s	remaining: 3.5s
# 826:	learn: 0.3581147	total: 16.7s	remaining: 3.48s
# 827:	learn: 0.3580867	total: 16.7s	remaining: 3.46s
# 828:	learn: 0.3580495	total: 16.7s	remaining: 3.44s
# 829:	learn: 0.3580179	total: 16.7s	remaining: 3.42s
# 830:	learn: 0.3579908	total: 16.7s	remaining: 3.4s
# 831:	learn: 0.3579643	total: 16.8s	remaining: 3.38s
# 832:	learn: 0.3579456	total: 16.8s	remaining: 3.36s
# 833:	learn: 0.3579169	total: 16.8s	remaining: 3.34s
# 834:	learn: 0.3579022	total: 16.8s	remaining: 3.32s
# 835:	learn: 0.3578679	total: 16.8s	remaining: 3.3s
# 836:	learn: 0.3578328	total: 16.9s	remaining: 3.29s
# 837:	learn: 0.3578075	total: 16.9s	remaining: 3.27s
# 838:	learn: 0.3577610	total: 16.9s	remaining: 3.25s
# 839:	learn: 0.3577210	total: 16.9s	remaining: 3.22s
# 840:	learn: 0.3576880	total: 16.9s	remaining: 3.2s
# 841:	learn: 0.3576632	total: 17s	remaining: 3.18s
# 842:	learn: 0.3576214	total: 17s	remaining: 3.16s
# 843:	learn: 0.3575885	total: 17s	remaining: 3.14s
# 844:	learn: 0.3575671	total: 17s	remaining: 3.12s
# 845:	learn: 0.3575451	total: 17.1s	remaining: 3.1s
# 846:	learn: 0.3574990	total: 17.1s	remaining: 3.08s
# 847:	learn: 0.3574590	total: 17.1s	remaining: 3.06s
# 848:	learn: 0.3574365	total: 17.1s	remaining: 3.04s
# 849:	learn: 0.3573988	total: 17.1s	remaining: 3.02s
# 850:	learn: 0.3573689	total: 17.1s	remaining: 3s
# 851:	learn: 0.3573289	total: 17.2s	remaining: 2.98s
# 852:	learn: 0.3573008	total: 17.2s	remaining: 2.96s
# 853:	learn: 0.3572710	total: 17.2s	remaining: 2.94s
# 854:	learn: 0.3572509	total: 17.2s	remaining: 2.92s
# 855:	learn: 0.3572369	total: 17.2s	remaining: 2.9s
# 856:	learn: 0.3571956	total: 17.3s	remaining: 2.88s
# 857:	learn: 0.3571844	total: 17.3s	remaining: 2.86s
# 858:	learn: 0.3571649	total: 17.3s	remaining: 2.84s
# 859:	learn: 0.3571272	total: 17.3s	remaining: 2.82s
# 860:	learn: 0.3571114	total: 17.3s	remaining: 2.8s
# 861:	learn: 0.3570833	total: 17.3s	remaining: 2.77s
# 862:	learn: 0.3570609	total: 17.4s	remaining: 2.75s
# 863:	learn: 0.3570185	total: 17.4s	remaining: 2.73s
# 864:	learn: 0.3569699	total: 17.4s	remaining: 2.71s
# 865:	learn: 0.3569341	total: 17.4s	remaining: 2.69s
# 866:	learn: 0.3569240	total: 17.4s	remaining: 2.67s
# 867:	learn: 0.3568942	total: 17.5s	remaining: 2.65s
# 868:	learn: 0.3568442	total: 17.5s	remaining: 2.63s
# 869:	learn: 0.3568116	total: 17.5s	remaining: 2.61s
# 870:	learn: 0.3567882	total: 17.5s	remaining: 2.59s
# 871:	learn: 0.3567603	total: 17.5s	remaining: 2.57s
# 872:	learn: 0.3567308	total: 17.6s	remaining: 2.55s
# 873:	learn: 0.3566980	total: 17.6s	remaining: 2.53s
# 874:	learn: 0.3566884	total: 17.6s	remaining: 2.51s
# 875:	learn: 0.3566574	total: 17.6s	remaining: 2.49s
# 876:	learn: 0.3566367	total: 17.6s	remaining: 2.47s
# 877:	learn: 0.3565913	total: 17.7s	remaining: 2.45s
# 878:	learn: 0.3565518	total: 17.7s	remaining: 2.43s
# 879:	learn: 0.3565384	total: 17.7s	remaining: 2.41s
# 880:	learn: 0.3565289	total: 17.7s	remaining: 2.39s
# 881:	learn: 0.3565024	total: 17.7s	remaining: 2.37s
# 882:	learn: 0.3564875	total: 17.7s	remaining: 2.35s
# 883:	learn: 0.3564785	total: 17.8s	remaining: 2.33s
# 884:	learn: 0.3564626	total: 17.8s	remaining: 2.31s
# 885:	learn: 0.3564141	total: 17.8s	remaining: 2.29s
# 886:	learn: 0.3563982	total: 17.8s	remaining: 2.26s
# 887:	learn: 0.3563764	total: 17.8s	remaining: 2.24s
# 888:	learn: 0.3563654	total: 17.8s	remaining: 2.22s
# 889:	learn: 0.3563350	total: 17.8s	remaining: 2.2s
# 890:	learn: 0.3563082	total: 17.8s	remaining: 2.18s
# 891:	learn: 0.3562807	total: 17.8s	remaining: 2.15s
# 892:	learn: 0.3562478	total: 17.8s	remaining: 2.13s
# 893:	learn: 0.3562206	total: 17.8s	remaining: 2.11s
# 894:	learn: 0.3561983	total: 17.8s	remaining: 2.09s
# 895:	learn: 0.3561628	total: 17.8s	remaining: 2.07s
# 896:	learn: 0.3561315	total: 17.8s	remaining: 2.05s
# 897:	learn: 0.3560996	total: 17.8s	remaining: 2.03s
# 898:	learn: 0.3560919	total: 17.8s	remaining: 2s
# 899:	learn: 0.3560758	total: 17.9s	remaining: 1.98s
# 900:	learn: 0.3560530	total: 17.9s	remaining: 1.96s
# 901:	learn: 0.3560238	total: 17.9s	remaining: 1.94s
# 902:	learn: 0.3560025	total: 17.9s	remaining: 1.92s
# 903:	learn: 0.3559633	total: 17.9s	remaining: 1.9s
# 904:	learn: 0.3559367	total: 17.9s	remaining: 1.88s
# 905:	learn: 0.3558854	total: 17.9s	remaining: 1.86s
# 906:	learn: 0.3558571	total: 17.9s	remaining: 1.83s
# 907:	learn: 0.3558230	total: 17.9s	remaining: 1.81s
# 908:	learn: 0.3557791	total: 17.9s	remaining: 1.79s
# 909:	learn: 0.3557388	total: 17.9s	remaining: 1.77s
# 910:	learn: 0.3556987	total: 17.9s	remaining: 1.75s
# 911:	learn: 0.3556593	total: 17.9s	remaining: 1.73s
# 912:	learn: 0.3556360	total: 17.9s	remaining: 1.71s
# 913:	learn: 0.3556163	total: 17.9s	remaining: 1.69s
# 914:	learn: 0.3555900	total: 17.9s	remaining: 1.67s
# 915:	learn: 0.3555611	total: 18s	remaining: 1.65s
# 916:	learn: 0.3555463	total: 18s	remaining: 1.63s
# 917:	learn: 0.3555027	total: 18s	remaining: 1.6s
# 918:	learn: 0.3554752	total: 18s	remaining: 1.58s
# 919:	learn: 0.3554245	total: 18s	remaining: 1.56s
# 920:	learn: 0.3554010	total: 18s	remaining: 1.54s
# 921:	learn: 0.3553614	total: 18s	remaining: 1.52s
# 922:	learn: 0.3553540	total: 18s	remaining: 1.5s
# 923:	learn: 0.3553175	total: 18s	remaining: 1.48s
# 924:	learn: 0.3552969	total: 18s	remaining: 1.46s
# 925:	learn: 0.3552582	total: 18s	remaining: 1.44s
# 926:	learn: 0.3552428	total: 18s	remaining: 1.42s
# 927:	learn: 0.3552283	total: 18s	remaining: 1.4s
# 928:	learn: 0.3551945	total: 18s	remaining: 1.38s
# 929:	learn: 0.3551720	total: 18.1s	remaining: 1.36s
# 930:	learn: 0.3551593	total: 18.1s	remaining: 1.34s
# 931:	learn: 0.3551321	total: 18.1s	remaining: 1.32s
# 932:	learn: 0.3550941	total: 18.1s	remaining: 1.3s
# 933:	learn: 0.3550683	total: 18.1s	remaining: 1.28s
# 934:	learn: 0.3550380	total: 18.1s	remaining: 1.26s
# 935:	learn: 0.3549953	total: 18.1s	remaining: 1.24s
# 936:	learn: 0.3549631	total: 18.1s	remaining: 1.22s
# 937:	learn: 0.3549469	total: 18.1s	remaining: 1.2s
# 938:	learn: 0.3549243	total: 18.1s	remaining: 1.18s
# 939:	learn: 0.3548961	total: 18.1s	remaining: 1.16s
# 940:	learn: 0.3548750	total: 18.1s	remaining: 1.14s
# 941:	learn: 0.3548500	total: 18.1s	remaining: 1.12s
# 942:	learn: 0.3548149	total: 18.1s	remaining: 1.1s
# 943:	learn: 0.3547834	total: 18.1s	remaining: 1.08s
# 944:	learn: 0.3547719	total: 18.1s	remaining: 1.06s
# 945:	learn: 0.3547541	total: 18.2s	remaining: 1.04s
# 946:	learn: 0.3547314	total: 18.2s	remaining: 1.02s
# 947:	learn: 0.3547096	total: 18.2s	remaining: 997ms
# 948:	learn: 0.3546870	total: 18.2s	remaining: 977ms
# 997:	learn: 0.3533027	total: 18.5s	remaining: 37ms
# 998:	learn: 0.3532690	total: 18.5s	remaining: 18.5ms
# 999:	learn: 0.3532551	total: 18.5s	remaining: 0us
# array([0.72147017, 0.71221046, 0.71449863, 0.70200787, 0.71357205])

# %%
y_pred_cbr = model_CBR.predict(x_test)

# %%
mae_cbr  = metrics.mean_absolute_error(y_test, y_pred_cbr)
mse_cbr  = metrics.mean_squared_error(y_test, y_pred_cbr)
rmse_cbr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_cbr))
r2_cbr   = metrics.r2_score(y_test, y_pred_cbr)


print('\nMean Absolute Error of CatBoost Regressor     : ', mae_cbr)
print('\nMean Squarred Error of CatBoost Regressor     : ', mse_cbr)
print('\nRoot Mean Squarred Error of CatBoost Regressor: ', rmse_cbr)
print('\nR2 Score of CatBoost Regressor                : ', r2_cbr)
# Out:
# Mean Absolute Error of CatBoost Regressor     :  0.2769374040423291
#
# Mean Squarred Error of CatBoost Regressor     :  0.14482482684900497
#
# Root Mean Squarred Error of CatBoost Regressor:  0.38055857216597416
#
# R2 Score of CatBoost Regressor                :  0.7203482264869523

# %% [markdown]
# # Gradient Boosting

# %%
gb = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3)

# %%
gb.fit(x_train, y_train)

y_pred_gb = gb.predict(x_test)

# %%
mae_gb  = metrics.mean_absolute_error(y_test, y_pred_gb)
mse_gb  = metrics.mean_squared_error(y_test, y_pred_gb)
rmse_gb = np.sqrt(metrics.mean_squared_error(y_test, y_pred_gb))
r2_gb   = metrics.r2_score(y_test, y_pred_gb)


print('\nMean Absolute Error of Gradient Boosting     : ', mae_gb)
print('\nMean Squarred Error of Gradient Boosting     : ', mse_gb)
print('\nRoot Mean Squarred Error of Gradient Boosting: ', rmse_gb)
print('\nR2 Score of Gradient Boosting                : ', r2_gb)
# Out:
# Mean Absolute Error of Gradient Boosting     :  0.3052618399619076
#
# Mean Squarred Error of Gradient Boosting     :  0.17018747706259144
#
# Root Mean Squarred Error of Gradient Boosting:  0.41253784924851616
#
# R2 Score of Gradient Boosting                :  0.6713738188005173

# %% [markdown]
# # XGBoost

# %%
# !pip install xgboost
xgb = XGBRegressor(objective='reg:squarederror')
# Out:
# Requirement already satisfied: xgboost in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (3.1.1)
# Requirement already satisfied: numpy in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from xgboost) (2.2.6)
# Requirement already satisfied: scipy in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from xgboost) (1.15.3)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 2
#       1 get_ipython().system('pip install xgboost')
# ----> 2 xgb = XGBRegressor(objective='reg:squarederror')
#
# NameError: name 'XGBRegressor' is not defined

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(objective='reg:squarederror')

# %%
xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb.predict(x_test)

# %%
mae_xgb  = metrics.mean_absolute_error(y_test, y_pred_xgb)
mse_xgb  = metrics.mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(metrics.mean_squared_error(y_test, y_pred_xgb))
r2_xgb   = metrics.r2_score(y_test, y_pred_xgb)


print('\nMean Absolute Error of XGBoost Regressor     : ', mae_xgb)
print('\nMean Squarred Error of XGBoost Regressor     : ', mse_xgb)
print('\nRoot Mean Squarred Error of XGBoost Regressor: ', rmse_xgb)
print('\nR2 Score of XGBoost Regressor                : ', r2_xgb)
# Out:
# Mean Absolute Error of XGBoost Regressor     :  0.2823860452633754
#
# Mean Squarred Error of XGBoost Regressor     :  0.14978968794775047
#
# Root Mean Squarred Error of XGBoost Regressor:  0.38702672769170665
#
# R2 Score of XGBoost Regressor                :  0.7107612499876971

# %%
r2_list = {"Linear Regression": r2_lr,
          "Random Forest": r2_rf ,
          "Polynomial Regression": r2_poly,
          "CatBoost": r2_cbr,
          "Gradient Boosting":r2_gb ,
          "XGBoost": r2_xgb}

mae_list = {"Linear Regression": mae_lr,
          "Random Forest": mae_rf ,
          "Polynomial Regression": mae_poly,
          "CatBoost": mae_cbr,
          "Gradient Boosting":mae_gb ,
          "XGBoost": mae_xgb}

mse_list = {"Linear Regression": mse_lr,
          "Random Forest": mse_rf ,
          "Polynomial Regression": mse_poly,
          "CatBoost": mse_cbr,
          "Gradient Boosting":mse_gb ,
          "XGBoost": mse_xgb}

rmse_list = {"Linear Regression": rmse_lr,
          "Random Forest": rmse_rf ,
          "Polynomial Regression": rmse_poly,
          "CatBoost": rmse_cbr,
          "Gradient Boosting":rmse_gb ,
          "XGBoost": rmse_xgb}

# %%
a1 =  pd.DataFrame.from_dict(r2_list, orient = 'index', columns = ["R2 SCORE"])
a2 =  pd.DataFrame.from_dict(mae_list, orient = 'index', columns = ["MEAN ABSOLUTE ERROR"])
a3 =  pd.DataFrame.from_dict(mse_list, orient = 'index', columns = ["MEAN SQUARRED ERROR"])
a4 =  pd.DataFrame.from_dict(rmse_list, orient = 'index', columns = ["ROOT MEAN SQUARRED ERROR"])

# %%
org = pd.concat([a1, a2, a3, a4], axis = 1)
org
# Out:
#                        R2 SCORE  MEAN ABSOLUTE ERROR  MEAN SQUARRED ERROR  \
# Linear Regression      0.546881             0.368704             0.234659
# Random Forest          0.699482             0.284036             0.155631
# Polynomial Regression  0.606372             0.342323             0.203851
# CatBoost               0.720348             0.276937             0.144825
# Gradient Boosting      0.671374             0.305262             0.170187
# XGBoost                0.710761             0.282386             0.149790
#
#                        ROOT MEAN SQUARRED ERROR
# Linear Regression                      0.484416
# Random Forest                          0.394501
# Polynomial Regression                  0.451498
# CatBoost                               0.380559
# Gradient Boosting                      0.412538
# XGBoost                                0.387027

# %%
alg = ['LR','RF','PR','CBR','GB','XGB']
plt.plot(alg,a1)
plt.plot(alg,a2)
plt.plot(alg,a3)
plt.plot(alg,a4)
legend = ["R2 SCORE", "MEAN ABSOLUTE ERROR", "MEAN SQUARRED ERROR", "ROOT MEAN SQUARRED ERROR"]

plt.title("METRICS COMPARISION")
plt.legend(legend, loc= 'right', fontsize='xx-small')
plt.show()

# %%
import pickle
pickle.dump(model_CBR, open("catboostalgo.pkl", "wb"))

# %% [markdown]
# # Model Monitoring

# %%
try:
    import evidently
except:
    # !pip install git+https://github.com/evidentlyai/evidently.git
# Out:
# Collecting git+https://github.com/evidentlyai/evidently.git
#   Cloning https://github.com/evidentlyai/evidently.git to C:\Users\DELL\AppData\Local\Temp\pip-req-build-m1v4qgul
#   Resolved https://github.com/evidentlyai/evidently.git to commit a4aa4c2b37fe7a4344cc5031f566deccf3d69e4f
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: certifi>=2024.7.4 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (2025.4.26)
# Requirement already satisfied: cryptography>=43.0.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (46.0.7)
# Collecting deprecation>=2.1.0 (from evidently==0.7.21)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting dynaconf>=3.2.4 (from evidently==0.7.21)
#   Downloading dynaconf-3.2.13-py2.py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: fsspec>=2024.9.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (2025.5.1)
# Collecting iterative-telemetry>=0.0.5 (from evidently==0.7.21)
#   Downloading iterative_telemetry-0.0.10-py3-none-any.whl.metadata (4.1 kB)
# Collecting litestar>=2.19.0 (from evidently==0.7.21)
#   Downloading litestar-2.24.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: nltk>=3.6.7 in C:\Users\DELL\anaconda3\Lib\site-packages (from evidently==0.7.21) (3.9.1)
# Requirement already satisfied: numpy>=1.23.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (2.2.6)
# Requirement already satisfied: opentelemetry-proto>=1.25.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (1.41.0)
# Requirement already satisfied: pandas>=1.3.5 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from pandas[parquet]>=1.3.5->evidently==0.7.21) (2.2.3)
# Requirement already satisfied: plotly<6,>=5.10.0 in C:\Users\DELL\anaconda3\Lib\site-packages (from evidently==0.7.21) (5.24.1)
# Requirement already satisfied: pydantic>=1.10.16 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (2.13.1)
# Requirement already satisfied: pyyaml>=6.0.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (6.0.2)
# Requirement already satisfied: requests>=2.32.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (2.34.2)
# Requirement already satisfied: rich>=13 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (15.0.0)
# Requirement already satisfied: scikit-learn>=1.1.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (1.6.1)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (1.15.3)
# Requirement already satisfied: statsmodels>=0.14.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (0.14.4)
# Requirement already satisfied: typer>=0.3 in C:\Users\DELL\anaconda3\Lib\site-packages (from evidently==0.7.21) (0.17.3)
# Collecting typing-inspect>=0.9.0 (from evidently==0.7.21)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: ujson>=5.4.0 in C:\Users\DELL\anaconda3\Lib\site-packages (from evidently==0.7.21) (5.10.0)
# Requirement already satisfied: urllib3>=1.26.19 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (2.4.0)
# Collecting uuid6>=2024.7.10 (from evidently==0.7.21)
#   Downloading uuid6-2025.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: uvicorn>=0.22.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.21) (0.44.0)
# Requirement already satisfied: watchdog>=3.0.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from evidently==0.7.21) (6.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from plotly<6,>=5.10.0->evidently==0.7.21) (9.1.2)
# Requirement already satisfied: packaging in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from plotly<6,>=5.10.0->evidently==0.7.21) (25.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from cryptography>=43.0.1->evidently==0.7.21) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from cffi>=2.0.0->cryptography>=43.0.1->evidently==0.7.21) (2.22)
# Requirement already satisfied: appdirs in C:\Users\DELL\anaconda3\Lib\site-packages (from iterative-telemetry>=0.0.5->evidently==0.7.21) (1.4.4)
# Requirement already satisfied: filelock in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from iterative-telemetry>=0.0.5->evidently==0.7.21) (3.18.0)
# Requirement already satisfied: distro in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from iterative-telemetry>=0.0.5->evidently==0.7.21) (1.9.0)
# Requirement already satisfied: anyio>=3 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from litestar>=2.19.0->evidently==0.7.21) (4.9.0)
# Requirement already satisfied: click in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from litestar>=2.19.0->evidently==0.7.21) (8.2.1)
# Requirement already satisfied: httpx>=0.22 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from litestar>=2.19.0->evidently==0.7.21) (0.28.1)
# Collecting litestar-htmx>=0.4.0 (from litestar>=2.19.0->evidently==0.7.21)
#   Downloading litestar_htmx-0.5.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting msgspec>=0.18.2 (from litestar>=2.19.0->evidently==0.7.21)
#   Downloading msgspec-0.21.1-cp313-cp313-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: multidict>=6.0.2 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from litestar>=2.19.0->evidently==0.7.21) (6.7.1)
# Collecting multipart>=1.2.0 (from litestar>=2.19.0->evidently==0.7.21)
#   Downloading multipart-1.3.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting polyfactory>=2.6.3 (from litestar>=2.19.0->evidently==0.7.21)
#   Downloading polyfactory-3.3.0-py3-none-any.whl.metadata (27 kB)
# Collecting rich-click (from litestar>=2.19.0->evidently==0.7.21)
#   Downloading rich_click-1.9.8-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: sniffio>=1.3.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from litestar>=2.19.0->evidently==0.7.21) (1.3.1)
# Requirement already satisfied: typing-extensions in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from litestar>=2.19.0->evidently==0.7.21) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from anyio>=3->litestar>=2.19.0->evidently==0.7.21) (3.10)
# Requirement already satisfied: httpcore==1.* in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from httpx>=0.22->litestar>=2.19.0->evidently==0.7.21) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from httpcore==1.*->httpx>=0.22->litestar>=2.19.0->evidently==0.7.21) (0.16.0)
# Requirement already satisfied: joblib in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from nltk>=3.6.7->evidently==0.7.21) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from nltk>=3.6.7->evidently==0.7.21) (2026.5.9)
# Requirement already satisfied: tqdm in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from nltk>=3.6.7->evidently==0.7.21) (4.67.1)
# Requirement already satisfied: protobuf<7.0,>=5.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from opentelemetry-proto>=1.25.0->evidently==0.7.21) (5.29.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.21) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.21) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.21) (2025.2)
# Requirement already satisfied: pyarrow>=10.0.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from pandas[parquet]>=1.3.5->evidently==0.7.21) (21.0.0)
# Collecting faker>=5.0.0 (from polyfactory>=2.6.3->litestar>=2.19.0->evidently==0.7.21)
#   Downloading faker-40.23.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from pydantic>=1.10.16->evidently==0.7.21) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from pydantic>=1.10.16->evidently==0.7.21) (2.46.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from pydantic>=1.10.16->evidently==0.7.21) (0.4.2)
# Requirement already satisfied: six>=1.5 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.21) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from requests>=2.32.0->evidently==0.7.21) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from rich>=13->evidently==0.7.21) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from rich>=13->evidently==0.7.21) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently==0.7.21) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from scikit-learn>=1.1.1->evidently==0.7.21) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from statsmodels>=0.14.0->evidently==0.7.21) (1.0.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\DELL\anaconda3\Lib\site-packages (from typer>=0.3->evidently==0.7.21) (1.5.0)
# Requirement already satisfied: colorama in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from click->litestar>=2.19.0->evidently==0.7.21) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\DELL\anaconda3\Lib\site-packages (from typing-inspect>=0.9.0->evidently==0.7.21) (1.0.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.22.0->evidently==0.7.21)
#   Downloading httptools-0.8.0-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.21) (1.2.2)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.22.0->evidently==0.7.21)
#   Downloading watchfiles-1.2.0-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=10.4 in C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.21) (16.0)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading dynaconf-3.2.13-py2.py3-none-any.whl (238 kB)
# Downloading iterative_telemetry-0.0.10-py3-none-any.whl (10 kB)
# Downloading litestar-2.24.0-py3-none-any.whl (581 kB)
#    ---------------------------------------- 0.0/581.8 kB ? eta -:--:--
#    ---------------------------------------- 581.8/581.8 kB 9.3 MB/s  0:00:00
# Downloading litestar_htmx-0.5.0-py3-none-any.whl (10.0 kB)
# Downloading msgspec-0.21.1-cp313-cp313-win_amd64.whl (189 kB)
# Downloading multipart-1.3.1-py3-none-any.whl (15 kB)
# Downloading polyfactory-3.3.0-py3-none-any.whl (62 kB)
# Downloading faker-40.23.0-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 17.3 MB/s  0:00:00
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uuid6-2025.0.1-py3-none-any.whl (7.0 kB)
# Downloading httptools-0.8.0-cp313-cp313-win_amd64.whl (90 kB)
# Downloading watchfiles-1.2.0-cp313-cp313-win_amd64.whl (288 kB)
# Downloading rich_click-1.9.8-py3-none-any.whl (72 kB)
# Building wheels for collected packages: evidently
#   Building wheel for evidently (pyproject.toml): started
#   Building wheel for evidently (pyproject.toml): finished with status 'done'
#   Created wheel for evidently: filename=evidently-0.7.21-py3-none-any.whl size=11752968 sha256=90a46ba62bddec61c285742a7000d13dd7f99469fe40a7b78db9b1250e867fad
#   Stored in directory: C:\Users\DELL\AppData\Local\Temp\pip-ephem-wheel-cache-2jdehzgt\wheels\66\d9\77\32fc56817f1d630daff250cd03b0e3f3e31eb278a038f25d17
# Successfully built evidently
# Installing collected packages: uuid6, typing-inspect, multipart, msgspec, litestar-htmx, httptools, faker, dynaconf, deprecation, watchfiles, polyfactory, iterative-telemetry, rich-click, litestar, evidently
#
#    ----- ----------------------------------  2/15 [multipart]
#    -------- -------------------------------  3/15 [msgspec]
#    ---------- -----------------------------  4/15 [litestar-htmx]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#   Running command git clone --filter=blob:none --quiet https://github.com/evidentlyai/evidently.git 'C:\Users\DELL\AppData\Local\Temp\pip-req-build-m1v4qgul'
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ---------------- -----------------------  6/15 [faker]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------ ---------------------  7/15 [dynaconf]
#    ------------------------ ---------------  9/15 [watchfiles]
#    -------------------------- ------------- 10/15 [polyfactory]
#    -------------------------- ------------- 10/15 [polyfactory]
#    -------------------------- ------------- 10/15 [polyfactory]
#    -------------------------- ------------- 10/15 [polyfactory]
#    -------------------------------- ------- 12/15 [rich-click]
#    -------------------------------- ------- 12/15 [rich-click]
#    -------------------------------- ------- 12/15 [rich-click]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ---------------------------------- ----- 13/15 [litestar]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ------------------------------------- -- 14/15 [evidently]
#    ---------------------------------------- 15/15 [evidently]
#
# Successfully installed deprecation-2.1.0 dynaconf-3.2.13 evidently-0.7.21 faker-40.23.0 httptools-0.8.0 iterative-telemetry-0.0.10 litestar-2.24.0 litestar-htmx-0.5.0 msgspec-0.21.1 multipart-1.3.1 polyfactory-3.3.0 rich-click-1.9.8 typing-inspect-0.9.0 uuid6-2025.0.1 watchfiles-1.2.0

# %%
import pandas as pd
import numpy as np
import requests
import io

from evidently import ColumnMapping
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset, RegressionPreset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[86], line 6
#       3 import requests
#       4 import io
# ----> 6 from evidently import ColumnMapping
#       7 from evidently.report import Report
#       8 from evidently.metric_preset import DataDriftPreset, TargetDriftPreset, RegressionPreset
#
# ImportError: cannot import name 'ColumnMapping' from 'evidently' (c:\Users\DELL\anaconda3\Lib\site-packages\evidently\__init__.py)

# %%
target = 'log_price'
prediction = 'prediction'
numerical_features = numerical_col
categorical_features = categorical_col

# %%
reference = df.loc[:25000]

current = df.loc[25000:]

# %%
regressor = model_CBR

# %%
regressor.fit(reference[numerical_features+categorical_features],reference[target])

# %%
ref_prediction = regressor.predict(reference[numerical_features+categorical_features])

current_prediction = regressor.predict(current[numerical_features+categorical_features])

# %%
reference['prediction'] = ref_prediction

current['prediction'] = current_prediction

# %%
column_mapping = ColumnMapping()

column_mapping.target = target
column_mapping.prediction = prediction
column_mapping.numerical_features = numerical_features
column_mapping.categorical_features = categorical_features

# %%
regression_perfomance = Report(metrics=[RegressionPreset()])
regression_perfomance.run(current_data=reference, reference_data=None, column_mapping=column_mapping)

# %%
regression_perfomance.show()
